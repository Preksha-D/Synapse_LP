# %% [markdown]
# <a href="https://colab.research.google.com/github/Preksha-D/Synapse_LP/blob/week2/Task2_Preksha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Synapse Week Two**
#
# ![image.png](data:image/png;base64,...)
#
# Last week, we dealt with the visualization and analytical aspect of ML. This week, lets directly get our hands dirty with various ML models.
#
# Possibly the first question one must ask is, what is Machine Learning essentially made up of? In a broad sense, ML problems can be split into Supervised and Unsupervised learning. In supervised learning are the categories of Classification and Regression, which is what we'll explore today.
#
# Like last time, resources and comments are provided above each cell, so peruse the resources and then get coding. Enough chitchat, lets get to work

# %% [markdown]
# Supervised vs Unsupervised vs Reinforcement Learning:
#
# https://www.simplilearn.com/tutorials/machine-learning-tutorial/types-of-machine-learning
#
# Regression vs Classification :
#
# https://www.analyticsvidhya.com/blog/2023/05/regression-vs-classification/ (Might be a little wordy)
#
# https://www.youtube.com/watch?v=1NBwM5tavTk&ab_channel=IntuitiveML
# (A very quick video)
#
# https://www.geeksforgeeks.org/ml-classification-vs-regression/
# (Short and Sweet)
#
# Machine Learning for Everyone (Read till 1.1):
#
# https://vas3k.com/blog/machine_learning/

# %% [markdown]
# Overfitting and Underfitting [VERY IMPORTANT]
# https://www.youtube.com/watch?v=T9NtOa-IITo

# %% [markdown]
# Lets import all the basic libraries.

# %%
# !pip install shap -q  #Will be used later on
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 8.2 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Regression

# %% [markdown]
# For regression we will use the car sales dataset - https://drive.google.com/file/d/1dtwer8INIz05mULkV5yk8-Fzk2r3K1Of/view?usp=sharing

# %% [markdown]
# #### Basic EDA

# %% [markdown]
# Import dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/Car_details.csv")

# %% [markdown]
# ##### Do .head, .info and .describe in the subsequent cells

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %% [markdown]
# ##### Plot a bar chart for the year, fuel and transmission columns

# %%
df['year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
df['fuel'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='fuel'>

# %%
df['transmission'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='transmission'>

# %% [markdown]
# ##### Plot a pie chart for the owner and seats column

# %%
df['owner'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['seats'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### Make a KDE plot to represent the engine column

# %% [markdown]
# ##### Since the engine column is of type object you'll need to convert it to float and round it to the nearest 10 place as it would be easier to count and plot

# %%
# code here
df['engine'] = df['engine'].str.replace('CC', '', regex=True).astype(float)
df['engine'] = df['engine'].round(-2)
sns.kdeplot(df['engine'], fill=True, color='purple')
plt.show()
# code ends

# %% [markdown]
# Plot the graph

# %% [markdown]
# ##### Also make a countplot for the Engine column
# hint: sns.countplot

# %%
#plot here
sns.countplot(data = df, x='engine')
plt.show()

# %% [markdown]
# ##### As you can see in the Name column the entire name of the car is given, it will be very difficut to perfrom EDA and feed in this column into our Regression model so we will just extract the car manufacturer's name and create a new column Brand

# %%
# code here
names = df['name'].str.split(' ',n=1, expand = True)
df[['Brand', 'name']] = names
df.head()
# code ends
# Out:
#                      name  year  selling_price  km_driven    fuel seller_type  \
# 0         Swift Dzire VDI  2014         450000     145500  Diesel  Individual
# 1  Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel  Individual
# 2      City 2017-2020 EXi  2006         158000     140000  Petrol  Individual
# 3       i20 Sportz Diesel  2010         225000     127000  Diesel  Individual
# 4         Swift VXI BSIII  2007         130000     120000  Petrol  Individual
#
#   transmission         owner     mileage  engine   max_power  \
# 0       Manual   First Owner   23.4 kmpl  1200.0      74 bhp
# 1       Manual  Second Owner  21.14 kmpl  1500.0  103.52 bhp
# 2       Manual   Third Owner   17.7 kmpl  1500.0      78 bhp
# 3       Manual   First Owner   23.0 kmpl  1400.0      90 bhp
# 4       Manual   First Owner   16.1 kmpl  1300.0    88.2 bhp
#
#                      torque  seats    Brand
# 0            190Nm@ 2000rpm    5.0   Maruti
# 1       250Nm@ 1500-2500rpm    5.0    Skoda
# 2     12.7@ 2,700(kgm@ rpm)    5.0    Honda
# 3  22.4 kgm at 1750-2750rpm    5.0  Hyundai
# 4     11.5@ 4,500(kgm@ rpm)    5.0   Maruti

# %% [markdown]
# ##### Plot a bar graph for the new column brand

# %%
#plot here
df['Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand'>

# %% [markdown]
# #### Perform a simiar process as Engine column for the Mileage column, extract the mileage number convert it to float and round it to the nearest 1's place

# %%
# code here
df['mileage'] = df['mileage'].str.extract('(\d+)')
df['mileage'] = df['mileage'].round(-1)
df.head()
# code ends
# Out:
#                      name  year  selling_price  km_driven    fuel seller_type  \
# 0         Swift Dzire VDI  2014         450000     145500  Diesel  Individual
# 1  Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel  Individual
# 2      City 2017-2020 EXi  2006         158000     140000  Petrol  Individual
# 3       i20 Sportz Diesel  2010         225000     127000  Diesel  Individual
# 4         Swift VXI BSIII  2007         130000     120000  Petrol  Individual
#
#   transmission         owner mileage  engine   max_power  \
# 0       Manual   First Owner      23  1200.0      74 bhp
# 1       Manual  Second Owner      21  1500.0  103.52 bhp
# 2       Manual   Third Owner      17  1500.0      78 bhp
# 3       Manual   First Owner      23  1400.0      90 bhp
# 4       Manual   First Owner      16  1300.0    88.2 bhp
#
#                      torque  seats    Brand
# 0            190Nm@ 2000rpm    5.0   Maruti
# 1       250Nm@ 1500-2500rpm    5.0    Skoda
# 2     12.7@ 2,700(kgm@ rpm)    5.0    Honda
# 3  22.4 kgm at 1750-2750rpm    5.0  Hyundai
# 4     11.5@ 4,500(kgm@ rpm)    5.0   Maruti

# %%
#plot the count of each mileage value
df['mileage'].value_counts().plot(kind='bar')
plt.show()
# code here

# %% [markdown]
# #### If you want to do more analysis and make some graphs you are more than welcome :)

# %% [markdown]
# ## What do you infer from the above analysis

# %% [markdown]
# ### Answer Here

# %% [markdown]
# ### Now let's prep our data to perform Regression to predict the Selling Price

# %% [markdown]
# ##### As you can see the column max_power is of type object, we need to extract the max_power similar to Engine and Mileage columns

# %% [markdown]
# Be careful of NaN values in this part of the code, perform df.info() to look how many Nan value are present, you might face diffculties when you are trying to convert object to float in Nan values are present

# %%
# code here
df['max_power'] = df['max_power'].str.replace(' bhp', '')
df['max_power'] = pd.to_numeric(df['max_power'], errors = 'coerce')
df.head()
# Out:
#                      name  year  selling_price  km_driven    fuel seller_type  \
# 0         Swift Dzire VDI  2014         450000     145500  Diesel  Individual
# 1  Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel  Individual
# 2      City 2017-2020 EXi  2006         158000     140000  Petrol  Individual
# 3       i20 Sportz Diesel  2010         225000     127000  Diesel  Individual
# 4         Swift VXI BSIII  2007         130000     120000  Petrol  Individual
#
#   transmission         owner mileage  engine  max_power  \
# 0       Manual   First Owner      23  1200.0      74.00
# 1       Manual  Second Owner      21  1500.0     103.52
# 2       Manual   Third Owner      17  1500.0      78.00
# 3       Manual   First Owner      23  1400.0      90.00
# 4       Manual   First Owner      16  1300.0      88.20
#
#                      torque  seats    Brand
# 0            190Nm@ 2000rpm    5.0   Maruti
# 1       250Nm@ 1500-2500rpm    5.0    Skoda
# 2     12.7@ 2,700(kgm@ rpm)    5.0    Honda
# 3  22.4 kgm at 1750-2750rpm    5.0  Hyundai
# 4     11.5@ 4,500(kgm@ rpm)    5.0   Maruti

# %%
# code ends
df
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 0            Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         City 2017-2020 EXi  2006         158000     140000  Petrol
# 3          i20 Sportz Diesel  2010         225000     127000  Diesel
# 4            Swift VXI BSIII  2007         130000     120000  Petrol
# ...                      ...   ...            ...        ...     ...
# 8123               i20 Magna  2013         320000     110000  Petrol
# 8124           Verna CRDi SX  2007         135000     119000  Diesel
# 8125         Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126              Indigo CR4  2013         290000      25000  Diesel
# 8127              Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner mileage  engine  \
# 0     Individual       Manual           First Owner      23  1200.0
# 1     Individual       Manual          Second Owner      21  1500.0
# 2     Individual       Manual           Third Owner      17  1500.0
# 3     Individual       Manual           First Owner      23  1400.0
# 4     Individual       Manual           First Owner      16  1300.0
# ...          ...          ...                   ...     ...     ...
# 8123  Individual       Manual           First Owner      18  1200.0
# 8124  Individual       Manual  Fourth & Above Owner      16  1500.0
# 8125  Individual       Manual           First Owner      19  1200.0
# 8126  Individual       Manual           First Owner      23  1400.0
# 8127  Individual       Manual           First Owner      23  1400.0
#
#       max_power                     torque  seats    Brand
# 0         74.00             190Nm@ 2000rpm    5.0   Maruti
# 1        103.52        250Nm@ 1500-2500rpm    5.0    Skoda
# 2         78.00      12.7@ 2,700(kgm@ rpm)    5.0    Honda
# 3         90.00   22.4 kgm at 1750-2750rpm    5.0  Hyundai
# 4         88.20      11.5@ 4,500(kgm@ rpm)    5.0   Maruti
# ...         ...                        ...    ...      ...
# 8123      82.85           113.7Nm@ 4000rpm    5.0  Hyundai
# 8124     110.00  24@ 1,900-2,750(kgm@ rpm)    5.0  Hyundai
# 8125      73.90             190Nm@ 2000rpm    5.0   Maruti
# 8126      70.00        140Nm@ 1800-3000rpm    5.0     Tata
# 8127      70.00        140Nm@ 1800-3000rpm    5.0     Tata
#
# [8128 rows x 14 columns]

# %% [markdown]
# ##### The year column contains the year the car was manufactured, but this data won't be directly useful to us
# ##### Use the current year to calculate the age of the car

# %%
# code here
df['age'] = 2024 - df['year']
# drop the columns year and name
df = df.drop(['year', 'name'], axis=1)
df.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#   mileage  engine  max_power                    torque  seats    Brand  age
# 0      23  1200.0      74.00            190Nm@ 2000rpm    5.0   Maruti   10
# 1      21  1500.0     103.52       250Nm@ 1500-2500rpm    5.0    Skoda   10
# 2      17  1500.0      78.00     12.7@ 2,700(kgm@ rpm)    5.0    Honda   18
# 3      23  1400.0      90.00  22.4 kgm at 1750-2750rpm    5.0  Hyundai   14
# 4      16  1300.0      88.20     11.5@ 4,500(kgm@ rpm)    5.0   Maruti   17

# %% [markdown]
# ##### A few of the columns are still of dtype object, now we will be using Laber Encoder to encode these columns

# %% [markdown]
# ##### Import LaberEncoder from sklearn

# %%
# import here
from sklearn.preprocessing import LabelEncoder
# now label encode the colums = ['fuel', 'seller_type', 'transmission', 'owner', 'Brand']
# code here
df['fuel']= LabelEncoder().fit_transform(df['fuel'])
df['seller_type']= LabelEncoder().fit_transform(df['seller_type'])
df['transmission']= LabelEncoder().fit_transform(df['transmission'])
df['owner']= LabelEncoder().fit_transform(df['owner'])
df['Brand']= LabelEncoder().fit_transform(df['Brand'])
# code ends

# %% [markdown]
# Do df.head() to see how your dataframe looks like after LabelEncoding

# %%
df = df.drop(['torque'], axis=1)
df.head()
# Out:
#    selling_price  km_driven  fuel  seller_type  transmission  owner mileage  \
# 0         450000     145500     1            1             1      0      23
# 1         370000     120000     1            1             1      2      21
# 2         158000     140000     3            1             1      4      17
# 3         225000     127000     1            1             1      0      23
# 4         130000     120000     3            1             1      0      16
#
#    engine  max_power  seats  Brand  age
# 0  1200.0      74.00    5.0     20   10
# 1  1500.0     103.52    5.0     27   10
# 2  1500.0      78.00    5.0     10   18
# 3  1400.0      90.00    5.0     11   14
# 4  1300.0      88.20    5.0     20   17

# %% [markdown]
# ##### The reason behind standardization and normalization will be explained in the later part of the task

# %% [markdown]
# ##### For now we need to Normalize somem specific coloums
# ##### Import MinMaxScaler from sklearn and normalize the coloums - ['km_driven', 'mileage', 'engine', 'max_power', 'seats', 'age', 'selling_price']

# %%
# import here
from sklearn.preprocessing import MinMaxScaler
# code here
cols = ['km_driven', 'mileage', 'engine', 'max_power', 'seats', 'age', 'selling_price']
df[cols] = MinMaxScaler().fit_transform(df[cols])
df.head()
#code ends
# Out:
#    selling_price  km_driven  fuel  seller_type  transmission  owner   mileage  \
# 0       0.042126   0.061640     1            1             1      0  0.547619
# 1       0.034102   0.050837     1            1             1      2  0.500000
# 2       0.012839   0.059310     3            1             1      4  0.404762
# 3       0.019559   0.053803     1            1             1      0  0.547619
# 4       0.010030   0.050837     3            1             1      0  0.380952
#
#      engine  max_power  seats  Brand       age
# 0  0.200000     0.1850   0.25     20  0.162162
# 1  0.300000     0.2588   0.25     27  0.162162
# 2  0.300000     0.1950   0.25     10  0.378378
# 3  0.266667     0.2250   0.25     11  0.270270
# 4  0.233333     0.2205   0.25     20  0.351351

# %%
# Fill NaN values in the dataset
df.fillna(df.mean(), inplace=True)

# %% [markdown]
# As mentioned above, the 'selling_price' column is what we're gonna be predicting. So essentially we need to create two additional dataframes, one which contains all the training features (All columns except 'selling_price') and one which only contains the column 'selling_price'. Name them X and y respectively.

# %%
# Seperate the Dataframe into X and y
y = df['selling_price']
X = df.drop(['selling_price'], axis = 1)

# %%
print(X.shape)
print(y.shape)
# Out:
# (8128, 11)
# (8128,)

# %% [markdown]
# ### Train-Test Split
#
# Implementation - https://www.youtube.com/watch?v=BUkqYGPnLZ8&ab_channel=ManifoldAILearning
#
# Now, while we need data to train our regression model, it is equally important to keep some data aside for testing the effectiveness of the aforementioned model. Thus the dataset as a whole is generally further divided into the training dataset and the testing dataset.
#
# In order to implement this, import train_test_split function from scikit-learn.

# %%
# import here
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=3)

# %% [markdown]
# Print the size and shape of each of the train/test splits (it should be in the ratio as per test_size parameter above, i.e in ratio of 0.3)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5689, 11)
# (2439, 11)
# (5689,)
# (2439,)

# %% [markdown]
# Can you see that the data has been divided into 2 datasets of size 70% and 30% of the original dataset each? Use your calculator to confirm this :)

# %% [markdown]
# ### We have preprocessed our DataFrame now we'll perform Regression on this Data

# %% [markdown]
# ### First lets understand Linear Regression, watch this video carefully it will be helpfull later on :)
#
# https://www.youtube.com/watch?v=7ArmBVF2dCs
#
# ### A quick article
# https://www.analyticsvidhya.com/blog/2021/08/understanding-linear-regression-with-mathematical-insights/

# %%
# perfrom linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
# perform linear regression

# create an instance of LinearRegression

linearReg = LinearRegression()

# %%
# fit the model on the training data, hint: use the fit method
linearReg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### The X_train and y_train dataframes have been used to train the model. Now we will use X_test and y_test to evaluate the efficiency of the model we have trained.

# %% [markdown]
# #### Use regressor.predict() on X_test and store it in a variable called "y_pred". Print type and size of the y_pred.
#
# #### Size should be (22009,) if everything is correct. Yeh line confirm karna hai

# %%
# make predictions on the test data
y_pred = linearReg.predict(X_test)
print(y_pred.shape)
# Out:
# (2439,)

# %%
# calculate the mean squared error
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 0.0020944841214124623

# %% [markdown]
# ### Visualize the predictions, plot a scatter plot of y_test vs y_pred and also plot the best fit line

# %%
#plot here
plt.scatter(y_test, y_pred)
a, b = np.polyfit(y_test, y_pred, 1)
plt.plot(y_test, a*y_test+b, color='orange', linestyle='--', linewidth=2)
plt.show()

# %% [markdown]
# # Now let's start the fun part :)

# %% [markdown]
# ### Have you ever wondered what happens when you call **'regressor.fit(X_train, y_train)'** ?

# %% [markdown]
# ### To understand what's hapenning in .fit method we will be implementing Linear Regression from scratch.

# %%
class LinearRegression() :

    def __init__( self, learning_rate, iterations ) :
        # initialize the learning rate and iterations provides by the user
        self.learning_rate = learning_rate

        self.iterations = iterations

    # Function for model training
    def fit( self, X, Y ) :

        # no_of_training_examples, no_of_features
        self.m, self.n = X.shape

        # what does self.m and self.n represent and why are they calculated? no of rows and column in the training data

        # weight initialization
        self.W = np.zeros(self.n)

        self.b = 0 # set this equal to 0

        self.X = X  # set this equal to X

        self.Y = Y# set this equal to Y


        # gradient descent learning
        for i in range(self.iterations) : # complete the range function

            self.update_weights()

        return self

    # Helper function to update weights in gradient descent
    def update_weights(self) :

        Y_pred = self.predict(self.X) # complete this line

        # calculate gradients
        dW = - ( 2 * ( self.X.T ).dot( self.Y - Y_pred )  ) / self.m
        db = - 2 * np.sum( self.Y - Y_pred ) / self.m

        # write the code to update the weights
        self.W = self.W - self.learning_rate * dW
        self.b = self.b - self.learning_rate * db
        return self


    def predict(self,X) :

        # return (self.W * self.X ) + self.b
        return X.dot( self.W ) + self.b

# %%
model = LinearRegression( iterations = 10000, learning_rate = 0.0001 )

model.fit(X_test, y_test) # Explain in your own words what the fit function does

# %% [markdown]
# The fit function collects the data provided to train itself to be able to make as accurate predictions as possible

# %% [markdown]
# #### Answer Here

# %%
y_pred = model.predict(X_test)
print(y_pred)# code here
# Out:
# 7228    0.065639
# 5183    0.043073
# 3360    0.089004
# 2696    0.010206
# 1352    0.042719
#           ...
# 3063    0.047122
# 7411    0.085171
# 2379    0.075528
# 5987    0.066147
# 7647    0.076383
# Length: 2439, dtype: float64

# %%
# Calculate the mean squared error
# mse = np.mean((y_test - y_pred)**2)
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 0.006089905084200905

# %%
# plot a similar scatter plot as above
plt.scatter(y_test, y_pred)
a, b = np.polyfit(y_test, y_pred, 1)
plt.plot(y_test, a*y_test+b, color='orange', linestyle='--', linewidth=2)
plt.show()

# %% [markdown]
# ## Classification

# %% [markdown]
# #### In the below cells, we are going to implement K Nearest Neighbour Classification.

# %% [markdown]
# Link to the dataset is here - https://drive.google.com/file/d/1bVOfBJYUr0JtZ7pp1lcyNamnHHXn_fDm/view?usp=sharing <br>
#
# Import the 'classified_data.txt' dataset using pandas and print the first five columns.
#
# Use "index_col" parameter to index the dataframe according to the first column. Otherwise, a new column would get created. Call this new dataframe 'df'.

# %%
df = pd.read_csv('/content/drive/MyDrive/classified_data.txt',index_col=0)
df.head()
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
#
#         PJF       HQE       NXJ  TARGET CLASS
# 0  0.643798  0.879422  1.231409             1
# 1  1.013546  0.621552  1.492702             0
# 2  1.154483  0.957877  1.285597             0
# 3  1.380003  1.522692  1.153093             1
# 4  0.646691  1.463812  1.419167             1

# %% [markdown]
# If you're wondering what these column names signify, well they are classified as the dataset name suggests. Our job here is to simply take the data at face value and build a model for classifying the target classes.

# %% [markdown]
# #### Basic EDA

# %% [markdown]
# ##### In the following two cells, use info() and describe() to get the data type and statistical summary of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WTT           1000 non-null   float64
#  1   PTI           1000 non-null   float64
#  2   EQW           1000 non-null   float64
#  3   SBI           1000 non-null   float64
#  4   LQE           1000 non-null   float64
#  5   QWG           1000 non-null   float64
#  6   FDJ           1000 non-null   float64
#  7   PJF           1000 non-null   float64
#  8   HQE           1000 non-null   float64
#  9   NXJ           1000 non-null   float64
#  10  TARGET CLASS  1000 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 93.8 KB

# %%
df.describe()
# Out:
#                WTT          PTI          EQW          SBI          LQE  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.949682     1.114303     0.834127     0.682099     1.032336
# std       0.289635     0.257085     0.291554     0.229645     0.243413
# min       0.174412     0.441398     0.170924     0.045027     0.315307
# 25%       0.742358     0.942071     0.615451     0.515010     0.870855
# 50%       0.940475     1.118486     0.813264     0.676835     1.035824
# 75%       1.163295     1.307904     1.028340     0.834317     1.198270
# max       1.721779     1.833757     1.722725     1.634884     1.650050
#
#                QWG          FDJ          PJF          HQE          NXJ  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.943534     0.963422     1.071960     1.158251     1.362725
# std       0.256121     0.255118     0.288982     0.293738     0.204225
# min       0.262389     0.295228     0.299476     0.365157     0.639693
# 25%       0.761064     0.784407     0.866306     0.934340     1.222623
# 50%       0.941502     0.945333     1.065500     1.165556     1.375368
# 75%       1.123060     1.134852     1.283156     1.383173     1.504832
# max       1.666902     1.713342     1.785420     1.885690     1.893950
#
#        TARGET CLASS
# count    1000.00000
# mean        0.50000
# std         0.50025
# min         0.00000
# 25%         0.00000
# 50%         0.50000
# 75%         1.00000
# max         1.00000

# %% [markdown]
# **Run a 'for' loop to draw boxplots of all the features for '0' and '1' TARGET CLASS**<br>
# ##### Hint: Loop through each of the 10 features and draw a separate boxplot. You should have 10 boxplots in total. <br>
# ##### Refer seaborn boxplot() documentation

# %%
#plot
for i in df.columns:
  sns.boxplot(x=df[i])
  plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# ##### What conclusion, if any can you draw from these boxplots?
# List them down below.

# %% [markdown]
# the data doesn't have a very wide range
# x axis inputs are not the same in all

# %% [markdown]
# ### Standardize the features using sklearn.preprocessing
# Why should we standardize?<br>
# Variables that are measured at different scales do not contribute equally to the model fitting & model learned function and might end up creating a bias. Thus, to deal with this potential problem feature-wise standardization is usually used prior to model fitting.<br><br>
#
# To give you an example, values pertaining to Age usually lie within the range of 1-100, however values pertaining to Salary lie in a much wider range of say 10000-1000000. You can see how having both columns be a part of a classification model as is would lead to an imbalance in importance assigned to columns.
# <br><br>
# Go through this link for a better understanding:<br>
# https://towardsdatascience.com/how-and-why-to-standardize-your-data-996926c2c832

# %% [markdown]
# ##### **import StandardScaler from Sklearn and instantiate it to a variable called "scaler"**

# %%
# your code starts here
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# your code ends here

# %% [markdown]
# ##### **Fit only the features data to this scaler (leaving the TARGET CLASS column out) and then transform**<br>
# ##### Hint: scaler.fit() and scaler.transform()

# %%
# your code starts here
scale = scaler.fit(df.drop('TARGET CLASS' ,axis=1))
df_std = scale.transform(df.drop('TARGET CLASS' ,axis=1))
# your code ends here

# %% [markdown]
# **scaler.transform() will return an array. We need to convert this into a dataframe. Do this and add the column names to the dataframe. Call this new dataframe as "df_feat". Call head() on this df**<br>
# Note: The final dataframe will have the initial columns except the "TARGET CLASS".

# %%
# your code starts here
df_feat = pd.DataFrame(df_std, columns = df.drop('TARGET CLASS' ,axis=1).columns)
df_feat.head()
# your code ends here
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0 -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375 -0.798951
# 1 -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706 -1.129797
# 2 -0.788702  0.339318  0.301511  0.755873  2.031693 -0.870156  2.599818
# 3  0.982841  1.060193 -0.621399  0.625299  0.452820 -0.267220  1.750208
# 4  1.139275 -0.640392 -0.709819 -0.057175  0.822886 -0.936773  0.596782
#
#         PJF       HQE       NXJ
# 0 -1.482368 -0.949719 -0.643314
# 1 -0.202240 -1.828051  0.636759
# 2  0.285707 -0.682494 -0.377850
# 3  1.066491  1.241325 -1.026987
# 4 -1.472352  1.040772  0.276510

# %% [markdown]
# ### Train/Test split

# %% [markdown]
# **Set X to be equal to df_feat and set y accordingly. As you know, X contains our training features and y contains our target.**<br>
# Hint: y can be taken directly from the initial dataframe "df"

# %%
X,y = df_feat.values[:,:],df.values[:,-1]

# %% [markdown]
# **Import train_test_split function from scikit-learn**<br>
# **Create X and y train and test splits in one command using a test size of 0.3 and a random seed**<br>
# They should be called X_train, X_test, y_train, y_test

# %%
# Your code starts here.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=3)
# Your code ends here

# %% [markdown]
# ### Model fit and training

# %% [markdown]
# Before moving ahead with the cells below, learn how the K Nearest Neighbour Algorithm actually works.
#
# Theory and implementation : https://youtu.be/wTF6vzS9fy4 <br>
# Theory: https://www.analyticsvidhya.com/blog/2018/08/k-nearest-neighbor-introduction-regression-python/

# %% [markdown]
# **import KNeighborsClassifier from sklearn and initialize it with neighbours = 1 (more on this later) . Fit this on X_train and y_train**

# %%
# Your code starts here.
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 1)
knn.fit(X_train, y_train)
# Your code ends here
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# **Using this fitted model, predict on X_test. Store these predictions in variable called pred.**

# %%
# Your code starts here.
pred = knn.predict(X_test)
# Your code ends here

# %% [markdown]
# **Let us check how correct these predictions are.<br>
# Print a classification report of y_test and pred**<br>
# Hint: sklearn classification_report

# %%
# Your code starts here.
from sklearn.metrics import classification_report
print(classification_report(pred, y_test))
# Your code ends here
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.90      0.90       149
#          1.0       0.90      0.91      0.90       151
#
#     accuracy                           0.90       300
#    macro avg       0.90      0.90      0.90       300
# weighted avg       0.90      0.90      0.90       300

# %% [markdown]
# #### Learn all about classification metrics - https://medium.com/analytics-vidhya/evaluation-metrics-for-classification-models-e2f0d8009d69

# %% [markdown]
# **Print the accuracy using numpy and round it to 3 decimal places.**

# %%
# Your code starts here.
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pred))
# Your code ends here
# Out:
# 0.9033333333333333

# %% [markdown]
# ##### Hey, not bad! But can we further improve this? Remember our arbitrary choice for n_neighbours? Can we improve that?

# %% [markdown]
# ### Choosing optimal 'k'

# %% [markdown]
# **Above, we chose n_neighbours to be equal to 1. Choosing a small value of K leads to unstable decision boundaries. <br>
# We need to select n_neighbours by calculating the accuracy for every value of n from 1 to 60 and then choosing the one which gives the highest accuracy.**

# %%
# Do the same as we did above, but this time make a loop from n = 1 to n = 60 and append the accuracy
# for each in a list

# Your code starts here.
accuracy_lst = {}
for i in range(1,60):
  knn = KNeighborsClassifier(n_neighbors = i)
  knn.fit(X_train,y_train)
  pred_i = knn.predict(X_test)
  accuracy_lst[i]= accuracy_score(y_test,pred_i)

# Your code ends here

# %% [markdown]
# ##### **Plot a graph of K value vs Accuracy**

# %%
# Your code starts here.
plt.plot(range(0,60), accuracy_lst.values())
# Your code ends here
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-e36bd54a04aa> in <cell line: 2>()
#       1 # Your code starts here.
# ----> 2 plt.plot(range(0,60), accuracy_lst.values())
#       3 # Your code ends here
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     502
#     503         if x.shape[0] != y.shape[0]:
# --> 504             raise ValueError(f"x and y must have same first dimension, but "
#     505                              f"have shapes {x.shape} and {y.shape}")
#     506         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (60,) and (59,)

# %% [markdown]
# ##### **Choose the best value of n_neighbours and give a reason why and also print the accuracy**

# %%
# Your code starts here.
n_acc_best = max(accuracy_lst.values())
n_neigh_best = max(accuracy_lst, key=accuracy_lst.get)
print("Best value of n_neighbours:",n_neigh_best)
print("Corresponding highest accuracy:",n_acc_best)
# Your code ends here
# Out:
# Best value of n_neighbours: 10
# Corresponding highest accuracy: 0.9533333333333334

# %% [markdown]
# ### OPTIONAL: Explainability

# %% [markdown]
# So you passed some data into a model, and trained it using that data. You then used some other data to test the accuracy of that model, and it now predicts values when you pass in some data. Ok. But how does it REALLY predict that value? How much is it relying on each individual feature column of data that you passed to the model? This is where the concept of explainability comes into picture, where you can understand for each data point, exactly what parameters led the model to predict the value that it has.

# %% [markdown]
# Info about explainable AI <br>
# https://www.ibm.com/topics/explainable-ai <br>
# About shap <br>
# https://shap.readthedocs.io/en/latest/example_notebooks/overviews/An%20introduction%20to%20explainable%20AI%20with%20Shapley%20values.html

# %%
#Run this code as it is
from shap import KernelExplainer, force_plot, sample

# %%
import shap

# %%
X_test = pd.DataFrame(X_test)
X_train = pd.DataFrame(X_train)
y_train = pd.DataFrame(y_train)
y_test = pd.DataFrame(y_test)

# %%
#Run this code as it is
ex = KernelExplainer(regressor.predict, sample(X_train, 10))  #only taking sample of 10 values for now
shap_values = ex.shap_values(X_test.iloc[0,:]) #explaining 1st tuple of the X_test dataframe
force_plot(ex.expected_value, shap_values, X_test.iloc[0,:], matplotlib=True)

# %% [markdown]
# ##### Plotting the same information in a different way

# %%
explainer_ebm = shap.Explainer(regressor.predict,sample(X_train, 10))
shap_values_ebm = explainer_ebm(X_train)
# Out:
# PermutationExplainer explainer: 6503it [00:49, 106.40it/s]

# %%
shap.plots.beeswarm(shap_values_ebm)

# %% [markdown]
# #### Can you see how the above plot visualizes which parameters contributed significantly to the prediction, and what were the actual values which led to the prediction?

# %% [markdown]
# RESEARCH TASK:

# %% [markdown]
# A)Logistic Regression

# %% [markdown]
# https://ryxcommar.com/2020/06/27/why-do-so-many-practicing-data-scientists-not-understand-logistic-regression/

# %% [markdown]
# B) Read the above article and write you understand
#
#
# What is a logit, probit?

# %% [markdown]
# C) Difference between logistic regression and classification

# %% [markdown]
# End of Task
#
# ©DJS Synapse 2024 - 2025
